# %%
import pandas as pd

df = pd.read_csv('cleaned_data\yelp_academic_dataset_business_cleaned.csv')

# %%
df.head()
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  tUFrWirKiKi_TAnsVWINQQ                    Target
# 2  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 3  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 4  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
#
#                            address          city state postal_code   latitude  \
# 0  87 Grasso Plaza Shopping Center        Affton    MO       63123  38.551126
# 1             5255 E Broadway Blvd        Tucson    AZ       85711  32.223236
# 2                      935 Race St  Philadelphia    PA       19107  39.955505
# 3                    101 Walnut St    Green Lane    PA       18054  40.338183
# 4                    615 S Main St  Ashland City    TN       37015  36.269593
#
#     longitude  stars  review_count  \
# 0  -90.335695    3.0            15
# 1 -110.880452    3.5            22
# 2  -75.155564    4.0            80
# ...

# %%
df.drop(columns=['categories_list', 'attributes', 'is_open'], inplace=True)

# %%
df.head()
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  tUFrWirKiKi_TAnsVWINQQ                    Target
# 2  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 3  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 4  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
#
#                            address          city state postal_code   latitude  \
# 0  87 Grasso Plaza Shopping Center        Affton    MO       63123  38.551126
# 1             5255 E Broadway Blvd        Tucson    AZ       85711  32.223236
# 2                      935 Race St  Philadelphia    PA       19107  39.955505
# 3                    101 Walnut St    Green Lane    PA       18054  40.338183
# 4                    615 S Main St  Ashland City    TN       37015  36.269593
#
#     longitude  stars  review_count  \
# 0  -90.335695    3.0            15
# 1 -110.880452    3.5            22
# 2  -75.155564    4.0            80
# ...

# %%
df.to_csv('cleaned_data\yelp_academic_dataset_business_cleaned.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114120 entries, 0 to 114119
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   114120 non-null  object
#  1   name          114120 non-null  object
#  2   address       114120 non-null  object
#  3   city          114120 non-null  object
#  4   state         114120 non-null  object
#  5   postal_code   114120 non-null  object
#  6   latitude      114120 non-null  float64
#  7   longitude     114120 non-null  float64
#  8   stars         114120 non-null  float64
#  9   review_count  114120 non-null  int64
#  10  categories    114120 non-null  object
#  11  hours         114120 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 10.4+ MB
